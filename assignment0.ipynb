# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika-470/python_programs_colab/blob/main/assignment0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Positive, Negative, or Zero
#Ask the user for a number and print:

num = float(input("enter a number:"))
if(num>0):
  print("positive")
elif(num<0):
  print("negative")
else:
  print("zero")
# Out:
# enter a number:5
# positive

# %%
#Check whether a number is even or odd.
num =int(input("enter a number:"))
if num%2==0:
  print("even")
else:
  print("odd")
# Out:
# enter a number:6
# even

# %%
#Check whether a person is eligible to vote (age >= 18).
age =int(input("enter a number:"))
if age>=18:
    print("eligiblity for vote")
else:
    print("not eligiblity for vote")
# Out:
# enter a number:98
# eligiblity for vote

# %%
#pass or fail
num = int(input("enter a number"))
if(num>=35):
  print("pass")
else:
  print("fail")
# Out:
# enter a number67
# pass

# %%
#5. Largest of Two Numbers
num1 = int(input("enter a  first number"))
num2 = int(input("enter a second number"))
if (num1>num2):
  print("num1 is largest")
else:
  print("num2 is largest")
# Out:
# enter a  first number45
# enter a second number67
# num2 is largest

# %%
#smallest of two numbers
num1 = int(input("enter a  first number"))
num2 = int(input("enter a second number"))
if (num1<num2):
  print("num1 is smallest")
else:
  print("num2 is smallest")
# Out:
# enter a  first number23
# enter a second number45
# num2 is smallest

# %%
#Check whether a number is divisible by 5
num1 = int(input("enter a number"))
if(num1%5==0):
  print("divisible by 5")
else:
    print("not divisible by 5")
# Out:
# enter a number75
# divisible by 5

# %%
#Check whether a number is divisible by 5 and 3
num1 = int(input("enter a number"))
if(num1%5 and num1%3==0):
  print("divisible by 5 and 3")
else:
    print("not divisible by 5 and 3")
# Out:
# enter a number45
# not divisible by 5 and 3

# %%
#Check whether a number is multiple of 2 or 7.
num = int(input("Enter a number: "))

if num % 2 == 0 or num % 7 == 0:
    print("Multiple of 2 or 7")
else:
    print("Not a multiple of 2 or 7")
# Out:
# Enter a number: 56
# Multiple of 2 or 7

# %%
#Check whether a number is between 1 and 100.
num = int(input("enter a number"))
if 1<=num<=100:
  print("range in 1to 100")
else:
  print("range outside")
# Out:
# enter a number34
# range in 1to 100

# %%
# largest of three numbers
num1 = int(input("enter a number"))
num2 = int(input("enter a number"))
num3 = int(input("enter a number"))
if(num1>num2 and num1>num3):
  print("num1 is largest")
elif(num2>num3):
  print("num2 is largest")
else:
  print("mun3 is largest")
# Out:
# enter a number56
# enter a number67
# enter a number32
# num2 is largest

# %%
#Calculate grade based on marks.
num1 = int(input("enter a number"))
if(num1>=90):
  print("a grade")
elif(num1>75):
  print("b grade")
elif(num1>50):
  print("c grade")
else:
  print("fail")
# Out:
# enter a number89
# b grade

# %%
#alphabet,digit,special charcter
ch=input("enter a charcter")
if ch.isalpha():
  print("character")
elif ch.isdigit():
  print("digit")
else:
  print("special character")
# Out:
# enter a charcter@
# special character

# %%
#Check whether entered character is vowel or consonant.
ch= input("enter a charcter").lower()
if  ch in ['a','e','i','o','u']:
  print("vowel")
else:
  print("consonants")
# Out:
# enter a charcteru
# vowel

# %%
#take two numbers arthmetics operations perform
num1=int(input("enter a first number"))
num2=int(input("enter a  second number"))
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# enter a first number5
# enter a  second number8
# 13
# -3
# 40
# 0.625

# %%
#atm pin verifiation
curent_pin ="2004"
pin = input("enter a pin:")
if pin == curent_pin:
  print("accessible")
else:
  print("not accesssible")
# Out:
# enter a pin:2004
# accessible

# %%
# correct username password
correct_username = "admin"
correct_password = "12345"

username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Username or Password")35
# Out:
# Enter username: admin
# Enter password: 12345
# Login Successful

# %%
#temperature
temp = float(input("Enter temperature: "))

if temp >= 35:
    print("Hot")
elif temp >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature: 35
# Hot

# %%
#movie ticket eligiblity
age = int(input("Enter your age: "))

if age >= 18:
    print("Movie Entry Allowed")
else:
    print("Access Denied")
# Out:
# Enter your age: 18
# Movie Entry Allowed
