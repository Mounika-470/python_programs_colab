# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika-470/python_programs_colab/blob/main/stringmethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
read="what,is you name."
x=read.capitalize()
print(x)
# Out:
# What,is you name.

# %%
name="mounika"
x=name.capitalize()
print(x)
# Out:
# Mounika

# %%
name="Mounika"
x=name.casefold()
print(x)
# Out:
# mounika

# %%
name="mounika"
x=name.upper()
print(x)
# Out:
# MOUNIKA

# %%
name="Mounika"
x=name.lower()
print(x)
# Out:
# mounika

# %%
name="mounika"
x=name.center(20)
print(x)
# Out:
#       mounika

# %%
name="mounika"
x=name.center(20,"0")
print(x)
# Out:
# 000000mounika0000000

# %%
name="mounika"
x=name.center(20,"2")
print(x)
# Out:
# 222222mounika2222222

# %%
name="mounika is very good mounika is nice mounika intelligent mounika is beauty"
x=name.count("mounika")
print(x)
# Out:
# 4

# %%
name="my name is mounika"
x=name.encode()
print(x)
# Out:
# b'my name is mounika'

# %%
name="mounika"
x=name.title()
print(x)
# Out:
# Mounika

# %%
name="mounika"
x=name.swapcase()
print(x)
# Out:
# MOUNIKA

# %%
name="mounika"
x=name.find("a")
print(x)
# Out:
# 6

# %%
name="mounika"
x=name.index("a")
print(x)
# Out:
# 6

# %%
name="mounika"
x=name.startswith("ka")
print(x)
# Out:
# False

# %%
name="mounika"
x=name.startswith("mo")
print(x)
# Out:
# True

# %%
name="mounika"
x=name.endswith("mo")
print(x)
# Out:
# False

# %%
name="mounika"
x=name.endswith("ka")
print(x)
# Out:
# True

# %%
name="mounika"
x=name.replace("mounika","kanna")
print(x)
# Out:
# kanna

# %%
name=" mounika "
x=name.strip()
print(x)
# Out:
# mounika

# %%
name=" mounika     "
x=name.lstrip()
print(x)
# Out:
# mounika

# %%
name="  mounika "
x=name.rstrip()
print(x)
# Out:
#   mounika

# %%
name="mounika"
x=name.split()
print(x)
# Out:
# ['mounika']

# %%
name="  mounika "
x=name.rsplit()
print(x)
# Out:
# ['mounika']

# %%
fruits = ["apple", "banana", "mango"]

result = ", ".join(fruits)

print(result)
# Out:
# apple, banana, mango

# %%
name="mounika1234"
x=name.isalnum()
print(x)
# Out:
# True

# %%
name="mounika1234"
x=name.isalpha()
print(x)
# Out:
# False

# %%
name="mounika"
x=name.isalpha()
print(x)
# Out:
# True

# %%
name="1234"
x=name.isdigit()
print(x)
# Out:
# True

# %%
name="mounika"
x=name.isupper()
print(x)
# Out:
# False

# %%
name="MOUNIKA"
x=name.isupper()
print(x)
# Out:
# True

# %%
name="mounika"
x=name.islower()
print(x)
# Out:
# True

# %%
name="MOUNIKA"
x=name.isspace()
print(x)
# Out:
# False
